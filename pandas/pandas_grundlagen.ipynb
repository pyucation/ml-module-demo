# %% [markdown]
# # Pandas Grundlagen
#
# ## Was ist pandas?
# Pandas ist eine der mächtigsten Bibliotheken für Python. Sie erlaubt es uns Daten sehr einfach zu strukturieren und zu analysiseren. Außerdem bietet es viele nützliche Funktionen, um bspw. "ungünstige" Datensätze zu bereinigen, oder statistische Grundfunktionalitäten auf einen Datensatz anzuwenden.\
# Dieses Tutorial basiert im Wesentlichen auf:
# - https://levelup.gitconnected.com/pandas-basics-cheat-sheet-2023-python-for-data-science-b59fb7786b4d
# - https://www.w3schools.com/python/pandas/pandas_intro.asp

# %%
import pandas as pd

# %% [markdown]
# Es gibt zwei grundlegende Datenstrukuren in pandas:
# - `Series`
# - `DataFrame`
#
# Series sind eindimensionale Arrays, während ein DataFrame eine zweidimensionale Tabelle darstellt. Man kann es sich ein bisschen wie eine Excel-Tabelle vorstellen.

# %%
# 'index' lässt uns einen eigenen Index benennen, standardmäßig würde es von 0
# an hochzählen
s = pd.Series([5, 1, -7, 8], index = ['a','b','c','d'])
print(s)
# Out:
# a    5
# b    1
# c   -7
# d    8
# dtype: int64

# %%
# ein Dictionary mit beliebigen Daten
data = {
    "Bundesland": ["Niedersachsen", "Bayern", "Berlin"],
    "Hauptstadt": ["Hannover", "München", None],
    "Einwohner": [8.03, 13.18, 3.68]
  }
# dataframe erstellen
df = pd.DataFrame(data)
print(df)
# Out:
#       Bundesland Hauptstadt  Einwohner
# 0  Niedersachsen   Hannover       8.03
# 1         Bayern    München      13.18
# 2         Berlin       None       3.68

# %%
# Information über den DataFrame ausgeben
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Bundesland  3 non-null      object
#  1   Hauptstadt  2 non-null      object
#  2   Einwohner   3 non-null      float64
# dtypes: float64(1), object(2)
# memory usage: 200.0+ bytes
# None

# %% [markdown]
# ### Mit Daten arbeiten

# %%
# excel tabelle einlesen
df = pd.read_excel("AW_Sales_Europe.xlsx")

# %%
# csv einlesen
data = pd.read_csv('Übungen/studenten_datensatz.csv', delimiter=';')
data.head()
# Out:
#         Name   Vorname  Matrikelnummer               Studienfach Abschluss  \
# 0   Peterson     Peter           72940       Literaturgeschichte  Bachelor
# 1     Hanson      Hans           97294     Politikwissenschaften  Bachelor
# 2  Johannson    Johann           15384                 Biochemie    Master
# 3     Maxson       Max           68536                Mathematik  Bachelor
# 4   Peterson  Stefanie           57284  Erziehungswissenschaften  Bachelor
#
#   Lieblingsfarbe  Abschlussnote  Alter
# 0           lila            1.3     23
# 1            rot            2.7     34
# 2           gelb            1.6     26
# 3            rot            1.9     21
# 4           blau            2.1     24

# %% [markdown]
# Die deskriptiven Statistiken natürlich mit Vorsicht genießen. In diesem Fall ergibt ein Mittelwert für `ProductKey` natürlich keinen Sinn.

# %%
# deskriptive Statistiken
df.describe()
# Out:
#          ProductKey  OrderQuantity     UnitPrice   SalesAmount  \
# count  17909.000000   17909.000000  17909.000000  17909.000000
# mean     428.041152       1.931599     58.770763    106.411749
# std      124.516658       2.522439    249.370337    428.802344
# min      213.000000       1.000000      1.330000      1.370000
# 25%      237.000000       1.000000      4.990000      7.950000
# 50%      479.000000       1.000000     22.790000     28.990000
# 75%      529.000000       1.000000     34.990000     53.990000
# max      606.000000      36.000000   3578.270000  13535.800000
#
#        TotalProductCost  DiscountAmount  ResellerKey   CustomerKey  \
# count      17909.000000    17909.000000  4473.000000  17909.000000
# mean          80.724383        0.586768   359.665996  14510.934837
# std          389.597002       10.612237   195.452192   9384.509691
# min            0.856500        0.000000    14.000000     14.000000
# 25%            2.973300        0.000000   176.000000  11238.000000
# 50%           10.842300        0.000000   355.000000  15692.000000
# 75%           38.492300        0.000000   535.000000  21869.000000
# max        15155.140000      762.902400   687.000000  29480.000000
#
#              Profit  NumberEmployees   AnnualSales  AnnualRevenue   YearOpened
# count  17909.000000      4473.000000  4.473000e+03    4473.000000  4473.000000
# mean      25.687355        56.011402  2.022938e+06  202293.762575  1992.274760
# std      109.938505        33.664770  1.027814e+06  102781.384349     8.178784
# min    -2876.142000         3.000000  3.000000e+05   30000.000000  1974.000000
# 25%        3.123700        19.000000  8.000000e+05   80000.000000  1987.000000
# 50%       12.417700        67.000000  3.000000e+06  300000.000000  1991.000000
# 75%       21.903700        87.000000  3.000000e+06  300000.000000  1998.000000
# max     1487.835600       100.000000  3.000000e+06  300000.000000  2005.000000

# %%
# prüfen, ob es fehlende Werte gibt
df.isna().any()
# Out:
# SalesOrderNumber      False
# ProductKey            False
# OrderQuantity         False
# UnitPrice             False
# SalesAmount           False
# TotalProductCost      False
# OrderDate             False
# ShipDate              False
# City                  False
# StateProvinceCode     False
# CountryRegionCode     False
# PostalCode            False
# DiscountAmount        False
# Sales Type            False
# ResellerKey            True
# CustomerKey           False
# ProductName           False
# ProductSubcategory    False
# ProductCategory       False
# Profit                False
# ResellerName           True
# NumberEmployees        True
# OrderFrequency         True
# AnnualSales            True
# AnnualRevenue          True
# YearOpened             True
# Region                False
# StoreAge               True
# dtype: bool

# %%
# aus einer Gruppe alle einzigartigen Werte erhalten
df["City"].unique()
# Out:
# array(['Frankfurt am Main', 'London', 'Warrington', 'Roncq', 'Berlin',
#        'Gloucestershire', 'Verrieres Le Buisson', 'Muehlheim',
#        'Courbevoie', 'Essen', 'Milton Keynes', 'Pantin', 'Duesseldorf',
#        'Wokingham', 'Saint Ouen', 'Colombes', 'Liverpool', 'Paris',
#        'Oxon', 'Orleans', 'Münster', 'W. York', 'Colomiers', 'Lieusaint',
#        'München', 'Lancaster', 'Bad Soden', 'Basingstoke Hants', 'Orly',
#        'Sulzbach Taunus', 'Grevenbroich', 'High Wycombe',
#        'Roissy en Brie', 'Reading', 'Offenbach', 'Abingdon', 'Bobigny',
#        'Paris La Defense', 'Stuttgart', 'West Sussex', 'York',
#        'Berkshire', 'Hamburg', 'Kiel', 'Birmingham', 'Hannover',
#        'Bracknell', 'Woolston', 'Saarbrücken', 'Maidenhead', 'Eilenburg',
#        'Berks', 'Cergy', 'Paderborn', 'Boulogne-sur-Mer', 'Braunschweig',
#        'Leipzig', 'Morangis', 'Augsburg', 'Cambridge', 'Frankfurt',
#        'Croix', 'Sèvres', 'Suresnes', 'Solingen', 'Watford', 'Les Ulis',
#        'Versailles', 'Esher-Molesey', 'Runcorn', 'Saint-Denis',
#        'Newcastle upon Tyne', 'Stoke-on-Trent', 'Hof', 'Bonn',
#        'Cheltenham', 'Oxford', 'Tremblay-en-France', 'Peterborough',
#        'Salzgitter', 'Werne', 'Metz', 'Boulogne-Billancourt', 'Saarlouis',
#        'Darmstadt', 'Gateshead', 'Saint Germain en Laye', 'Kassel',
#        'Ingolstadt', 'Kirkby', 'Roubaix', 'Poing', 'Bottrop',
#        "Villeneuve-d'Ascq", 'Lille', 'Chatou', 'Drancy', 'Neunkirchen',
#        'Erlangen', 'Dunkerque', 'Leeds', 'Billericay', 'Mühlheim', 'Bury',
#        'Dresden'], dtype=object)

# %% [markdown]
# ### Daten filtern

# %%
data_augsburg = df[df["City"] == "Augsburg"].copy()

# %%
data_augsburg.head()
# Out:
#      SalesOrderNumber  ProductKey  OrderQuantity  UnitPrice  SalesAmount  \
# 3945          SO58902         548              1      48.59        48.59
# 3946          SO71834         548              1      48.59        48.59
# 3947          SO71834         554              1      54.94        54.94
# 3948          SO53516         557              1     153.89       153.89
# 3949          SO58902         558              1     242.99       242.99
#
#       TotalProductCost  OrderDate   ShipDate      City StateProvinceCode  ...  \
# 3945           35.9596 2019-03-22 2019-01-27  Augsburg                BY  ...
# 3946           35.9596 2019-09-18 2019-07-28  Augsburg                BY  ...
# 3947           40.6571 2019-09-18 2019-07-28  Augsburg                BY  ...
# 3948          113.8816 2018-12-18 2018-10-29  Augsburg                BY  ...
# 3949          179.8156 2019-03-22 2019-01-27  Augsburg                BY  ...
#
#      ProductCategory   Profit       ResellerName NumberEmployees  \
# 3945      Components  12.6344  Rustic Bike Store            12.0
# 3946      Components  12.6344  Rustic Bike Store            12.0
# 3947      Components  14.2849  Rustic Bike Store            12.0
# 3948      Components  40.0124  Rustic Bike Store            12.0
# 3949      Components  63.1784  Rustic Bike Store            12.0
#
#       OrderFrequency  AnnualSales AnnualRevenue YearOpened Region  StoreAge
# 3945               S     800000.0       80000.0     1980.0     EU   veryold
# 3946               S     800000.0       80000.0     1980.0     EU   veryold
# 3947               S     800000.0       80000.0     1980.0     EU   veryold
# 3948               S     800000.0       80000.0     1980.0     EU   veryold
# 3949               S     800000.0       80000.0     1980.0     EU   veryold
#
# [5 rows x 28 columns]

# %%
# Filtern nach einer spezifischen Bedingung (zweites Beispiel)
filtered_data = data[data['Abschlussnote'] < 2.0]

# %% [markdown]
# ### Indizierung in DataFrames

# %%
# Zugriff auf eine spezifische Spalte
data['Studienfach']
# Zugriff auf mehrere Spalten
data[['Name', 'Vorname', 'Abschlussnote']]
# Out:
#          Name    Vorname  Abschlussnote
# 0    Peterson      Peter            1.3
# 1      Hanson       Hans            2.7
# 2   Johannson     Johann            1.6
# 3      Maxson        Max            1.9
# 4    Peterson   Stefanie            2.1
# 5      Müller  Franziska            1.2
# 6     Schmitt  Hannelore            1.5
# 7   Gustavson     Gustav            3.1
# 8       Meyer     Andrea            2.4
# 9    Baerbock   Annalena            1.2
# 10     Lustig      Peter            2.9

# %% [markdown]
# ### Gruppieren von Daten

# %%
# Daten gruppieren nach Stadt, Produktkategorie und Produktname
# und nur relevante Spalten anzeigen und den Mittelwert berechnen
df.groupby(["City", "ProductCategory", "ProductName"])[["SalesAmount", "TotalProductCost", "Profit"]].mean()
# Out:
#                                                           SalesAmount  \
# City     ProductCategory ProductName
# Abingdon Clothing        Racing Socks, L                        29.67
# Augsburg Clothing        Short-Sleeve Classic Jersey, XL       226.76
#                          Women's Mountain Shorts, S            125.98
#          Components      Front Derailleur                       54.89
#                          HL Crankset                           242.99
# ...                                                               ...
# York     Clothing        Women's Mountain Shorts, L             69.99
#                          Women's Mountain Shorts, M             69.99
#                          Women's Mountain Shorts, S             69.99
#          Components      HL Touring Handlebars                 109.88
#                          Touring Pedal                          48.59
#
#                                                           TotalProductCost  \
# City     ProductCategory ProductName
# Abingdon Clothing        Racing Socks, L                          18.49265
# Augsburg Clothing        Short-Sleeve Classic Jersey, XL         291.00610
#                          Women's Mountain Shorts, S               78.52890
#          Components      Front Derailleur                         40.62160
#                          HL Crankset                             179.81560
# ...                                                                    ...
# York     Clothing        Women's Mountain Shorts, L               26.17630
#                          Women's Mountain Shorts, M               26.17630
#                          Women's Mountain Shorts, S               26.17630
#          Components      HL Touring Handlebars                    81.31420
#                          Touring Pedal                            35.95960
#
#                                                             Profit
# City     ProductCategory ProductName
# Abingdon Clothing        Racing Socks, L                  11.17435
# Augsburg Clothing        Short-Sleeve Classic Jersey, XL -64.24810
#                          Women's Mountain Shorts, S       47.45310
#          Components      Front Derailleur                 14.27240
#                          HL Crankset                      63.17840
# ...                                                            ...
# York     Clothing        Women's Mountain Shorts, L       43.81370
#                          Women's Mountain Shorts, M       43.81370
#                          Women's Mountain Shorts, S       43.81370
#          Components      HL Touring Handlebars            28.56980
#                          Touring Pedal                    12.63440
#
# [4299 rows x 3 columns]

# %%
# Gruppieren nach 'Studienfach' und Berechnung des Durchschnitts der Noten
grouped_data = data.groupby('Studienfach')['Abschlussnote'].mean()
grouped_data
# Out:
# Studienfach
# Agrarwirtschaft             1.20
# Biochemie                   1.90
# Erziehungswissenschaften    2.10
# Literaturgeschichte         1.85
# Mathematik                  1.90
# Politikwissenschaften       2.90
# Romanistik                  1.50
# Name: Abschlussnote, dtype: float64

# %% [markdown]
# ### iloc vs loc
#
# `iloc` steht für "integer location" und wird verwendet, um auf Daten über deren numerischen Index zuzugreifen. Es verwendet nur ganzzahlige Indizes zur Auswahl und funktioniert ähnlich wie die Indizierung in Python-Listen. Hier sind einige Beispiele für die Verwendung von `iloc`:<br>
#     - `data.iloc[0]` gibt die erste Zeile des DataFrames zurück.<br>
#     - `data.iloc[:, 1]` gibt die zweite Spalte des DataFrames zurück.<br>
#     - `data.iloc[1:5]` gibt die Zeilen von Index 1 bis 4 (ausschließlich 5) zurück.<br>
#     - `data.iloc[1:5, 0:2]` gibt die Zeilen von Index 1 bis 4 und die Spalten von Index 0 bis 1 zurück.<br>
#
# `loc` hingegen steht für "location" und wird verwendet, um auf Daten über deren Label oder Namen zuzugreifen. Es kann Indizes basierend auf dem Namen der Zeilen- oder Spaltenlabel verwenden. Hier sind einige Beispiele, wie `loc` benutzt werden kann:<br>
#     - `data.loc[0]` gibt die Zeile zurück, deren Index-Label 0 ist (dies muss nicht die erste Zeile sein, falls der Index nicht standardmäßig von 0 an aufsteigend ist).<br>
#     - `data.loc[:, 'Name']` gibt die Spalte Name zurück.<br>
#     - `data.loc['a':'b']` gibt Zeilen zurück, deren Index-Label zwischen a und b einschließlich liegt.<br>
#     - `data.loc[data['Alter'] > 20]` gibt Zeilen zurück, in denen das Alter über 20 ist.<br>
#     - `data.loc[1:5, ['Name', 'Alter']]` gibt die Zeilen von 1 bis 5 und die Spalten Name und Alter zurück.<br>
